# %%
# %pip install yfinance pandas
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------- ----------------------------- 0.8/3.0 MB 3.6 MB/s eta 0:00:01
#      ------------------------------- -------- 2.4/3.0 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 5.7 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 4.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 4.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 4.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 4.7 MB/s eta 0:00:01
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_indian_stocks_data(symbol, days=30):
  stock=yf.Ticker(f"{symbol}.NS")
  df=stock.history(period=f"{days}d")
  return df[["Close", "Volume"]]

# %%
def add_volume_analysis(df, periods=50):
    df["Volume_MA"]=df["Volume"].rolling(window=period, min_periods=1).mean()
    return df

# %%
def add_moving_averages(df):
    df["SMA_50"]=df["Close"].rolling(wimdows=50, min_periods=1).mean()
    df["SMA_200"]=df["Close"].rolling(wimdows=200, min_periods=1).mean()
    df["EMA_20"]=df["Close"].ewm(span=20, adjust=False).mean()
    return df

# %%
def calculate_rsi(df, period=14):
    """Calculates RSI for a given stock DataFrame."""
    delta = df["Close"].diff(1)   #Get daily price change
    gain = (delta.where(delta > 0, 0)).rolling(window=period, min_periods=1).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period, min_periods=1).mean()
    rs = gain / loss
    df[f"RSI_{period}"] = 100 - (100 / (1 + rs))
    return df

# %%
def add_volume_analysis(df, volume_window=20):
    # Calculate moving averages of volume (e.g., 20-day and 50-day)
    df['20_day_vol_ma'] = df['Volume'].rolling(window=20).mean()
    df['50_day_vol_ma'] = df['Volume'].rolling(window=50).mean()

    # Align the 'Volume' and '20_day_vol_ma' before comparing
    df = df.copy()  # Create a copy to avoid SettingWithCopyWarning
    df['Volume'], df['20_day_vol_ma'] = df['Volume'].align(df['20_day_vol_ma'], axis=0)  

    # Identify volume spikes (e.g., when volume exceeds 2 times the 20-day moving average)
    df['volume_spike'] = df['Volume'] > (2 * df['20_day_vol_ma'])
    
    return df

# %%
# %pip install seaborn
# %pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install google.generativeai
# Out:
# ...
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.0/1.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.1 MB 5.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/13.1 MB 6.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/13.1 MB 6.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/13.1 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/13.1 MB 6.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/13.1 MB 6.2 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/13.1 MB 6.2 MB/s eta 0:00:01
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import google.generativeai as genai

GOOGLE_API_KEY = "AIzaSyAqr4G3mZADJCB27VnSYEy2UoWr855iyfs"
genai.configure(api_key=GOOGLE_API_KEY)

def get_indian_stock_data(symbol, days=30):
    stock = yf.Ticker(f"{symbol}.NS")
    df = stock.history(period=f"{days}d")
    return df[["Close", "Volume"]]

def add_volume_analysis(df, period=50):
    df["Volume_MA"] = df["Volume"].rolling(window=period, min_periods=1).mean()
    return df

def add_moving_averages(df):
    df["SMA_50"] = df["Close"].rolling(window=50, min_periods=1).mean()
    df["SMA_200"] = df["Close"].rolling(window=200, min_periods=1).mean()
    df["EMA_20"] = df["Close"].ewm(span=20, adjust=False).mean()
    return df


def calculate_rsi(df, period=16):
    """Calculates RSI for a given stock DataFrame."""
    delta = df["Close"].diff(1)  # Get daily price change
    gain = (delta.where(delta > 0, 0)).rolling(window=period, min_periods=1).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period, min_periods=1).mean()
    rs = gain / loss
    df[f"RSI_{period}"] = 100 - (100 / (1 + rs))
    return df


def get_gemini_stock_insight(symbol, df):
    """Generates AI-powered technical analysis using Gemini AI."""

    # Extract latest values
    latest_close = df["Close"].iloc[-1]
    latest_sma_50 = df["SMA_50"].iloc[-1]
    latest_sma_200 = df["SMA_200"].iloc[-1]
    latest_ema_20 = df["EMA_20"].iloc[-1]
    latest_rsi_14 = df["RSI_14"].iloc[-1]
    latest_volume = df["Volume"].iloc[-1]
    latest_volume_ma = df["Volume_MA"].iloc[-1]

    # Prepare prompt for Gemini AI
    prompt = f"""
    Stock Symbol: {symbol}
    - Latest Close Price: {latest_close}
    - 50-day SMA: {latest_sma_50}
    - 200-day SMA: {latest_sma_200}
    - 20-day EMA: {latest_ema_20}
    - 14-day RSI: {latest_rsi_14}
    - Latest Trading Volume: {latest_volume}
    - 50-day Average Volume: {latest_volume_ma}

    Based on these indicators:
    0. Cuurent Price of the stock is {latest_close}
    1. Analyze if the stock is in a bullish or bearish trend.
    2. Suggest potential buy/sell opportunities.
    3. Highlight key support/resistance levels.
    4. Provide insights on volume trends and RSI signals.
    5. Give a trading recommendation based on the current trend.
    6. Also tell other stocks within same range.
    """

    # Call Gemini AI for analysis
    model = genai.GenerativeModel("gemini-1.5-pro")
    response = model.generate_content(prompt)

    return response.text


def analyze_stock(symbol, days=90):
  stock_data = get_indian_stock_data(symbol, days)
  stock_data = add_volume_analysis(stock_data, 50);
  stock_data = add_moving_averages(stock_data);
  stock_data = calculate_rsi(stock_data, 14);
  ai_insight = get_gemini_stock_insight(symbol, stock_data);
  return ai_insight;

symbol = "WAAREEENER"
insight = analyze_stock(symbol)
print(insight)


# Function to fetch stock data and plot it
def plot_stock_analysis(ticker_symbol, start_date='2020-01-01', end_date='2025-03-12'):
    # Fetch stock data using yfinance (ensure to use the NSE ticker format, e.g., WAAREEENER)
    stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
    
    # Plot the stock's closing price over time
    plt.figure(figsize=(12, 6))
    plt.plot(stock_data['Close'], label=f'{ticker_symbol} Closing Price', color='blue')
    
    # Add labels and title
    plt.title(f'{ticker_symbol} Stock Price Analysis (Indian Stock)')
    plt.xlabel('Date')
    plt.ylabel('Price (INR)')
    
    # Show the legend
    plt.legend()
    
    # Show the plot
    plt.grid(True)
    plt.show()

# Example usage: Plot stock data for Reliance Industries (RELIANCE.NS)
plot_stock_analysis('WAAREEENER.NS')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Based on the provided indicators, WAAREEENER appears to be in a **bearish trend**. Here's a breakdown:
#
# 1. **Trend Analysis:** Both the 50-day SMA (2339.76) and the 200-day SMA (2601.92) are above the current price (2138.05), indicating a downtrend. The 20-day EMA (2196.78) is also above the current price, reinforcing the bearish sentiment.  The price being below both key moving averages suggests the bears are in control.
#
# 2. **Potential Buy/Sell Opportunities:**
#     * **Sell:**  The current trend is bearish, so selling or shorting the stock might be considered. However, the RSI is approaching oversold territory, so a bounce is possible.  Wait for a small rally before considering a short position.
# ...
